# %% [markdown]
# <a href="https://colab.research.google.com/github/ExTc-aShiSh/Introduction-to-AI/blob/main/Hill_Climb_algo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
# Objective function
def objective_function(x):
    return -x**2 + 2*x + 1  # Example objective function
# Neighbor function: this will generate a neighboring solution by moving a small step.
def get_neighbors(x, step_size=0.1):
    return [x - step_size, x + step_size]
# Hill Climbing Algorithm
def hill_climbing():
    # Start with a random initial solution
    current_solution = random.uniform(-10, 10)  # Random start point between -10 and 10
    current_value = objective_function(current_solution)

    # Iteratively improve the solution
    while True:
        neighbors = get_neighbors(current_solution)
        # Evaluate the neighbors
        next_solution = None
        next_value = current_value

        for neighbor in neighbors:
            neighbor_value = objective_function(neighbor)
            if neighbor_value > next_value:  # Select the neighbor with the higher value
                next_solution = neighbor
                next_value = neighbor_value

        # If no better neighbor is found, exit
        if next_value <= current_value:
            break

        # Move to the better neighbor
        current_solution = next_solution
        current_value = next_value

    return current_solution, current_value

# Run Hill Climbing algorithm
best_solution, best_value = hill_climbing()
print(f"Best solution: {best_solution}, with value: {best_value}")
# Out:
# Best solution: 0.9515154513754076, with value: 1.9976492485446695

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the range for x
x_values = np.linspace(-5, 5, 400) # Generate 400 points between -5 and 5

# Calculate y values using the objective function
y_values = [objective_function(x) for x in x_values]

# Plot the objective function
plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='Objective Function: $-x^2 + 2x + 1$')

# Plot the best solution found by Hill Climbing
plt.scatter(best_solution, best_value, color='red', s=100, zorder=5, label=f'Hill Climbing Max: ({best_solution:.2f}, {best_value:.2f})')

plt.title('Graph of the Objective Function with Hill Climbing Maxima')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.axvline(x=0, color='grey', linestyle='--', linewidth=0.8)
plt.axhline(y=0, color='grey', linestyle='--', linewidth=0.8)
plt.show()
